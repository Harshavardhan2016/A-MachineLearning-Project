# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifa_20 = pd.read_csv('players_20.csv')
fifa_19 = pd.read_csv('players_19.csv')
fifa_18 = pd.read_csv('players_18.csv')
fifa_17 = pd.read_csv('players_17.csv')
fifa_16 = pd.read_csv('players_16.csv')
fifa_15 = pd.read_csv('players_15.csv')

# %%
fifa_20['year'] = 20
fifa_19['year'] = 19
fifa_18['year'] = 18
fifa_17['year'] = 17
fifa_16['year'] = 16
fifa_15['year'] = 15

# %%
fifa_20.shape, fifa_19.shape, fifa_18.shape, fifa_17.shape, fifa_16.shape,fifa_15.shape
# Out:
# ((18278, 105),
#  (17770, 105),
#  (17592, 105),
#  (17009, 105),
#  (14881, 105),
#  (15465, 105))

# %%
fifa = pd.concat([fifa_20, fifa_19, fifa_18, fifa_17, fifa_16,fifa_15])

# %%
# import sys
# print(sys.executable)

# %%
# ! <path-to-the-executable>/python -m pip install wordcloud

# %%
list(fifa.columns)
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
#  'mentality_penalties',
#  'mentality_composure',
#  'defending_marking',
#  'defending_standing_tackle',
#  'defending_sliding_tackle',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw',
#  'lam',
#  'cam',
#  'ram',
#  'lm',
#  'lcm',
#  'cm',
#  'rcm',
#  'rm',
#  'lwb',
#  'ldm',
#  'cdm',
#  'rdm',
#  'rwb',
#  'lb',
#  'lcb',
#  'cb',
#  'rcb',
#  'rb',
#  'year']

# %%
# ! conda install -c conda-forge wordcloud=1.8.1

# %%
from wordcloud import WordCloud


d_frame = fifa.club

plt.subplots(figsize=(15,15))
wordcloud = WordCloud(
                   background_color='white',
                        width = 2000,
                        height = 1200
    ).generate(" ".join(d_frame))

plt.imshow(wordcloud)
plt.axis('off')
# plt.savefig('wordcloud.png')
# Out:
# (-0.5, 1999.5, 1199.5, -0.5)

# %%
# https://1.bp.blogspot.com/-gUGQXSRszOI/YGN765-YpDI/AAAAAAAALKQ/lPEO2feNwkkT37_o9I8_RecHyU78S8pbQCK4BGAYYCw/s400/CaptureM3.PNG

# %%
from wordcloud import WordCloud


d_frame = fifa_20.club

plt.subplots(figsize=(15,15))
wordcloud = WordCloud(
                   background_color='white',
                        width = 2000,
                        height = 1200
    ).generate(" ".join(d_frame))

plt.imshow(wordcloud)
plt.axis('off')
# plt.savefig('wordcloud.png')
# Out:
# (-0.5, 1999.5, 1199.5, -0.5)

# %%
list(fifa.columns)
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
#  'mentality_penalties',
#  'mentality_composure',
#  'defending_marking',
#  'defending_standing_tackle',
#  'defending_sliding_tackle',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw',
#  'lam',
#  'cam',
#  'ram',
#  'lm',
#  'lcm',
#  'cm',
#  'rcm',
#  'rm',
#  'lwb',
#  'ldm',
#  'cdm',
#  'rdm',
#  'rwb',
#  'lb',
#  'lcb',
#  'cb',
#  'rcb',
#  'rb',
#  'year']

# %%
ty=fifa['club'].value_counts().keys()[:7]

# %%
kill=fifa[fifa['club'].isin(ty)]

# %%
import plotly.express as px
import numpy as np
# df = px.data.gapminder().query("year == 2007")
fig = px.sunburst(kill, path=['year', 'club'], #values='pop',
#                   color='year'
                 )
fig.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\DELL\anaconda3\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <div>                            <div id="aea6b3ee-3700-4b12-b544-f8d24561c6db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aea6b3ee-3700-4b12-b544-f8d24561c6db")) {                    Plotly.newPlot(                        "aea6b3ee-3700-4b12-b544-f8d24561c6db",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["15/Arsenal","16/Arsenal","17/Arsenal","18/Arsenal","19/Arsenal","20/Arsenal","15/Crystal Palace","16/Crystal Palace","17/Crystal Palace","18/Crystal Palace","19/Crystal Palace","20/Crystal Palace","15/Leicester City","16/Leicester City","17/Leicester City","18/Leicester City","19/Leicester City","20/Leicester City","15/Manchester City","16/Manchester City","17/Manchester City","18/Manchester City","19/Manchester City","20/Manchester City","15/Southampton","16/Southampton","17/Southampton","18/Southampton","19/Southampton","20/Southampton","15/Tottenham Hotspur","16/Tottenham Hotspur","17/Tottenham Hotspur","18/Tottenham Hotspur","19/Tottenham Hotspur","20/Tottenham Hotspur","15/West Ham United","16/West Ham United","17/West Ham United","18/West Ham United","19/West Ham United","20/West Ham United","15","16","17","18","19","20"],"labels":["Arsenal","Arsenal","Arsenal","Arsenal","Arsenal","Arsenal","Crystal Palace","Crystal Palace","Crystal Palace","Crystal Palace","Crystal Palace","Crystal Palace","Leicester City","Leicester City","Leicester City","Leicester City","Leicester City","Leicester City","Manchester City","Manchester City","Manchester City","Manchester City","Manchester City","Manchester City","Southampton","Southampton","Southampton","Southampton","Southampton","Southampton","Tottenham Hotspur","Tottenham Hotspur","Tottenham Hotspur","Tottenham Hotspur","Tottenham Hotspur","Tottenham Hotspur","West Ham United","West Ham United","West Ham United","West Ham United","West Ham United","West Ham United","15","16","17","18","19","20"],"name":"","parents":["15","16","17","18","19","20","15","16","17","18","19","20","15","16","17","18","19","20","15","16","17","18","19","20","15","16","17","18","19","20","15","16","17","18","19","20","15","16","17","18","19","20","","","","","",""],"values":[33,32,33,33,33,33,33,29,33,33,33,33,33,31,33,33,33,33,33,29,33,33,33,33,33,31,33,33,33,33,33,30,33,33,33,33,32,31,33,33,33,33,230,213,231,231,231,231],"type":"sunburst"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"], ...

# %%
tt=pd.read_csv('teams_and_leagues.csv')

# %%
ty=list(tt['league_name'].value_counts().keys()[15])
lo=tt[tt['league_name'].isin(ty)]

# %%
fig = px.sunburst(lo, path=['league_name','club'], #values='pop',
#                   color='year'
                 )
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [75], in <cell line: 1>()
# ----> 1 fig = px.sunburst(lo, path=['league_name','club'], #values='pop',
#       2 #                   color='year'
#       3                  )
#       4 fig.show()
#
# File ~\anaconda3\lib\site-packages\plotly\express\_chart_types.py:1521, in sunburst(data_frame, names, values, parents, path, ids, color, color_continuous_scale, range_color, color_continuous_midpoint, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, branchvalues, maxdepth)
#    1519 if path is not None and branchvalues is None:
#    1520     branchvalues = "total"
# -> 1521 return make_figure(
#    1522     args=locals(),
#    1523     constructor=go.Sunburst,
#    1524     trace_patch=dict(branchvalues=branchvalues, maxdepth=maxdepth),
#    1525     layout_patch=layout_patch,
#    1526 )
#
# File ~\anaconda3\lib\site-packages\plotly\express\_core.py:1945, in make_figure(args, constructor, trace_patch, layout_patch)
#    1942 layout_patch = layout_patch or {}
#    1943 apply_default_cascade(args)
# -> 1945 args = build_dataframe(args, constructor)
#    1946 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1947     args = process_dataframe_hierarchy(args)
#
# File ~\anaconda3\lib\site-packages\plotly\express\_core.py:1405, in build_dataframe(args, constructor)
#    1402     args["color"] = None
#    1403 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1405 df_output, wide_id_vars = process_args_into_dataframe(
#    1406     args, wide_mode, var_name, value_name
#    1407 )
#    1409 # now that `df_output` exists and `args` contains only references, we complete
#    1410 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1411 # df_output
#    1413 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~\anaconda3\lib\site-packages\plotly\express\_core.py:1207, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1205         if argument == "index":
#    1206             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1207         raise ValueError(err_msg)
#    1208 elif length and len(df_input[argument]) != length:
#    1209     raise ValueError(
#    1210         "All arguments should have the same length. "
#    1211         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1218         )
#    1219     )
#
# ValueError: Value of 'path_1' is not the name of a column in 'data_frame'. Expected one of ['url', 'league_name'] but received: club

# %%
fifa.shape
# Out:
# (85530, 105)

# %%
leagues_consider = ['English Premier League', 'German 1. Bundesliga', 'French Ligue 1', 'Spain Primera Division', 'Italian Serie A']

# %%
team_and_league = pd.read_csv('teams_and_leagues.csv')

# %%
team_and_league.head()
# Out:
#    url              league_name
# 0  241  Spain Primera Division
# 1   11  English Premier League
# 2    5  English Premier League
# 3  243  Spain Primera Division
# 4    1  English Premier League

# %%
team_and_league.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   url          1080 non-null   int64
#  1   league_name  1080 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 17.0+ KB

# %%
fifa['club'].nunique()
# Out:
# 892

# %%
fifa['short_name'].nunique()
# Out:
# 31584

# %%
team_and_league[team_and_league['url']==113173]
# Out:
#         url           league_name
# 652  113173  Swedish Allsvenskan

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\dell\anaconda3\lib\site-packages (4.64.0)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from tqdm) (0.4.4)

# %%
clubs = []

# importing the modules
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
for i in tqdm(list(team_and_league['url'].unique())):
    # target url
    url = f'https://sofifa.com/team/{i}/'

    # making requests instance
    reqs = requests.get(url)

    # using the BeautifulSoup module
    soup = BeautifulSoup(reqs.text, 'html.parser')


    for title in soup.find_all('title'):
        titl = title.get_text()
    club_name = titl[:titl.find('FIFA ')-1]
    clubs.append(club_name)
# Out:
#  27%|█████████████████████▊                                                            | 268/1009 [03:27<08:20,  1.48it/s]

# %%
#     url = f'https://sofifa.com/team/1/'

#     # making requests instance
#     reqs = requests.get(url)

#     # using the BeautifulSoup module
#     soup = BeautifulSoup(reqs.text, 'html.parser')


#     for title in soup.find_all('title'):
#         titl = title.get_text()
#     print(titl)

# %%
url_club = {}
for i, j in zip(list(team_and_league['url'].unique()), clubs):
    url_club[i] = j

# %%
clubs = []
for i in team_and_league['url']:
    clubs.append(url_club[i])

team_and_league['club'] = clubs

# %%
team_and_league.head()

# %%
team_and_league['league_name'] = team_and_league['league_name'].str.rstrip()

# %% [markdown]
# ### Changes

# %%
# cv=team_and_league['club'].unique()

# %%
# fifa[fifa['club'].isin(cv)]

# %%
# ram=set(fifa['club'].unique()).difference(set(fifa[fifa['club'].isin(cv)]['club'].unique()))

# %%
# fifa[fifa['club'].isin(ram)]

# %%
# fifa.shape

# %%
fifa_t = fifa.copy()

# %%
rem = ['sofifa_id', 'player_url', 'short_name', 'long_name', 'dob', 'nationality', 'player_positions', 'preferred_foot','wage_eur', 'player_tags','work_rate','team_position','nation_position','nation_jersey_number','player_traits','contract_valid_until','loaned_from', 'joined','real_face']

# %%
fifa_t=fifa_t[list(set(fifa_t.columns).difference(set(rem)))]

# %%
fifa_t = fifa_t[fifa_t['body_type'].isin(['Normal', 'Lean', 'Stocky'])]

# %%
rep = {'Normal':1, 'Lean':0, 'Stocky':2}
fifa_t.replace(rep, inplace=True)

# %%
fifa_t_df = fifa_t.fillna(0)

# %%
def add_up(x):
    if '-' in str(x):
        a = str(x).split('-')
        a = list(map(float, a))
        return a[0]-a[1]
    a = str(x).split('+')
    a = list(map(float, a))
    return sum(a)

# %%
for i in fifa_t_df.columns:
    if i not in ['year', 'club']:
        fifa_t_df[i] = fifa_t_df[i].apply(add_up)

# %%
fifa_grouped = fifa_t_df.groupby(['club', 'year']).mean()

clubs = fifa_t_df['club'].unique()

# %%
year = [17, 18, 19, 20]
l=[]
for i in clubs:
    for j in year:
        if (i,j) in fifa_grouped.index and (i, j-1) in fifa_grouped.index:
            diff = fifa_grouped.loc[(i,j)] - fifa_grouped.loc[(i, j-1)]
            diff_df = pd.DataFrame(diff).T
            diff_df['club'] = i
#             diff_df['year'] = f'{j}-{j-1}'
            l.append(diff_df)
        else:
            pass

# %%
new_diff_df = pd.concat(l)

# %%
new_diff_df.set_index('club', inplace=True)

# %%
k = []
for i in clubs:
    df = new_diff_df.loc[i]
    if len(df.shape)>1:
        meaned_diff = pd.DataFrame(df.mean(axis=0)).T
    meaned_diff['club'] = i
    k.append(meaned_diff)

# %%
final_t = pd.concat(k)

# %%
final_t.set_index('club', inplace=True)
final_t.head()

# %%
final_scores = pd.DataFrame()
for i in final_t.columns:
    means = final_t[i]
    max_ = np.max(means)
    min_ = np.min(means)
    temp=[]
    for j in means:
        temp.append(((j-min_)*100)/(max_-min_))
    final_scores[i] = temp
final_scores['club'] = final_t.index

# %%
final_scores.set_index('club', inplace=True)

# %%
total_score = pd.DataFrame(final_scores.mean(axis=1), columns=['score'])

total_score.sort_values(by='score', ascending=False, inplace=True)

total_score.reset_index(inplace=True)

# %%
ranks = total_score.reset_index()

ranks.drop('score', axis=1, inplace=True)

ranks.columns=['rank', 'club']
ranks['rank'] = ranks['rank']+1
ranks = ranks[['club', 'rank']]

# %% [markdown]
# ## Test

# %%
teams_consider = team_and_league[team_and_league['league_name'].isin(leagues_consider)]
teams_consider.reset_index(drop=True, inplace=True)

# %%
teams_consider.shape
# Out:
# (147, 3)

# %%
teams_consider['league_name'].unique()

# %%
clubs_consider = teams_consider['club'].unique()

# %%
fifa_df = fifa[fifa['club'].isin(clubs_consider)]

# %%
fifa.shape, fifa_df.shape

# %%
features = list(fifa_df.columns)

# %%
final_feats = list(set(features).difference(set(rem)))

# %%
len(final_feats)

# %%
fifa_final = fifa_df[final_feats]

# %%
fifa_final.shape

# %%
fifa_final.info()

# %%
fifa_final = fifa_final[fifa_final['body_type'].isin(['Normal', 'Lean', 'Stocky'])]

# %%
fifa_final.shape

# %%
rep = {'Normal':1, 'Lean':0, 'Stocky':2}
fifa_final.replace(rep, inplace=True)

# %%
fifa_final_df = fifa_final.fillna(0)

# %%
fifa_final_df.shape

# %%
fifa_final_df.groupby('year')['club'].nunique()

# %%
for i in fifa_final_df.columns:
    if i not in ['year', 'club']:
        fifa_final_df[i] = fifa_final_df[i].apply(add_up)

# %%
fifa_final_df.info()

# %%
fifa_grouped = fifa_final_df.groupby(['club', 'year']).mean()

# %%
clubs = fifa_final_df['club'].unique()

# %%
len(clubs)

# %%
year = [17, 18, 19, 20]

# %%
new_fifa_diff = pd.DataFrame()

# %%
l=[]
for i in clubs:
    for j in year:
        if (i,j) in fifa_grouped.index and (i, j-1) in fifa_grouped.index:
            diff = fifa_grouped.loc[(i,j)] - fifa_grouped.loc[(i, j-1)]
            diff_df = pd.DataFrame(diff).T
            diff_df['club'] = i
#             diff_df['year'] = f'{j}-{j-1}'
            l.append(diff_df)
        else:
            pass

# %%
new_diff_df = pd.concat(l)

# %%
new_diff_df.shape

# %%
new_diff_df.set_index('club', inplace=True)

# %%
len(new_diff_df.loc['Manchester City'].iloc[0].shape)

# %%
pd.DataFrame(new_diff_df.loc['Manchester City'].mean()).T

# %%
k = []
for i in clubs:
    df = new_diff_df.loc[i]
    if len(df.shape)>1:
        meaned_diff = pd.DataFrame(df.mean(axis=0)).T
    meaned_diff['club'] = i
    k.append(meaned_diff)

# %%
final_df = pd.concat(k)

# %%
final_df.shape

# %%
final_df['club'].nunique()

# %%
final_df.set_index('club', inplace=True)
final_df.head()

# %%
final_scores = pd.DataFrame()
for i in final_df.columns:
    means = final_df[i]
    max_ = np.max(means)
    min_ = np.min(means)
    temp=[]
    for j in means:
        temp.append(((j-min_)*100)/(max_-min_))
    final_scores[i] = temp
final_scores['club'] = final_df.index

# %%
final_scores.head()

# %%
final_scores.set_index('club', inplace=True)

# %%
total_score = pd.DataFrame(final_scores.mean(axis=1), columns=['score'])

# %%
total_score.head()

# %%
total_score.sort_values(by='score', ascending=False, inplace=True)

# %%
total_score.reset_index(inplace=True)

# %%
total_score.head()

# %%
# total_score.to_csv('scores.csv', index=False)

# %%
ranks = total_score.reset_index()

# %%
ranks.drop('score', axis=1, inplace=True)

# %%
ranks.columns=['rank', 'club']
ranks['rank'] = ranks['rank']+1
ranks = ranks[['club', 'rank']]

# %%
ranks.head()

# %%
# ranks.to_csv('fifa_ranks.csv', index=False)
